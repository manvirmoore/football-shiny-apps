# %% [markdown]
# # Brighton and Hove Albion 2024-25 Season

# %% [markdown]
# ## Player stats

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
players = pd.read_csv("player_stats.csv")
players
# Out:
#          player_name     Season       Squad                 Comp  MP  Gls  \
# 0    Bart Verbruggen  2019-2020   NAC Breda    2. Eerste Divisie   0  NaN
# 1    Bart Verbruggen  2020-2021  Anderlecht  1. First Division A   0  NaN
# 2    Bart Verbruggen  2021-2022  Anderlecht  1. First Division A   0  NaN
# 3    Bart Verbruggen  2022-2023  Anderlecht           3. Conf Lg   6  0.0
# 4    Bart Verbruggen  2022-2023  Anderlecht      1. Pro League A  17  0.0
# ..               ...        ...         ...                  ...  ..  ...
# 681     Harry Howell  2024-2025    Brighton              Jr. PL2  17  8.0
# 682     Harry Howell  2024-2025    Brighton    1. Premier League   0  NaN
# 683       Joe Knight  2023-2024    Brighton              Jr. PL2   8  0.0
# 684       Joe Knight  2024-2025    Brighton              Jr. PL2  14  0.0
# 685       Joe Knight  2024-2025    Brighton    1. Premier League   0  NaN
#
#      Ast   G+A
# 0    NaN   NaN
# 1    NaN   NaN
# 2    NaN   NaN
# 3    0.0   0.0
# 4    0.0   0.0
# ..   ...   ...
# 681  4.0  12.0
# 682  NaN   NaN
# 683  0.0   0.0
# 684  0.0   0.0
# 685  NaN   NaN
#
# [686 rows x 8 columns]

# %% [markdown]
# ## Goals

# %%
goals = pd.read_csv("season_results.csv")
goals
# Out:
#           Date         Opponent            Comp         Round Venue Result  \
# 0   2024-08-17          Everton  Premier League   Matchweek 1  Away      W
# 1   2024-08-24   Manchester Utd  Premier League   Matchweek 2  Home      W
# 2   2024-08-31          Arsenal  Premier League   Matchweek 3  Away      D
# 3   2024-09-14     Ipswich Town  Premier League   Matchweek 4  Home      D
# 4   2024-09-22  Nott'ham Forest  Premier League   Matchweek 5  Home      D
# 5   2024-09-28          Chelsea  Premier League   Matchweek 6  Away      L
# 6   2024-10-06        Tottenham  Premier League   Matchweek 7  Home      W
# 7   2024-10-19    Newcastle Utd  Premier League   Matchweek 8  Away      W
# 8   2024-10-26           Wolves  Premier League   Matchweek 9  Home      D
# 9   2024-11-02        Liverpool  Premier League  Matchweek 10  Away      L
# 10  2024-11-09  Manchester City  Premier League  Matchweek 11  Home      W
# 11  2024-11-23      Bournemouth  Premier League  Matchweek 12  Away      W
# 12  2024-11-29      Southampton  Premier League  Matchweek 13  Home      D
# 13  2024-12-05           Fulham  Premier League  Matchweek 14  Away      L
# 14  2024-12-08   Leicester City  Premier League  Matchweek 15  Away      D
# 15  2024-12-15   Crystal Palace  Premier League  Matchweek 16  Home      L
# 16  2024-12-21         West Ham  Premier League  Matchweek 17  Away      D
# 17  2024-12-27        Brentford  Premier League  Matchweek 18  Home      D
# 18  2024-12-30      Aston Villa  Premier League  Matchweek 19  Away      D
# 19  2025-01-04          Arsenal  Premier League  Matchweek 20  Home      D
# 20  2025-01-16     Ipswich Town  Premier League  Matchweek 21  Away      W
# 21  2025-01-19   Manchester Utd  Premier League  Matchweek 22  Away      W
# 22  2025-01-25          Everton  Premier League  Matchweek 23  Home      L
# 23  2025-02-01  Nott'ham Forest  Premier League  Matchweek 24  Away      L
# 24  2025-02-14          Chelsea  Premier League  Matchweek 25  Home      W
# 25  2025-02-22      Southampton  Premier League  Matchweek 26  Away      W
# 26  2025-02-25      Bournemouth  Premier League  Matchweek 27  Home      W
# 27  2025-03-08           Fulham  Premier League  Matchweek 28  Home      W
# 28  2025-03-15  Manchester City  Premier League  Matchweek 29  Away      D
# 29  2025-04-02      Aston Villa  Premier League  Matchweek 30  Home      L
# 30  2025-04-05   Crystal Palace  Premier League  Matchweek 31  Away      L
# 31  2025-04-12   Leicester City  Premier League  Matchweek 32  Home      D
# 32  2025-04-19        Brentford  Premier League  Matchweek 33  Away      L
# 33  2025-04-26         West Ham  Premier League  Matchweek 34  Home      W
#
#     GF  GA   xG  xGA  GD
# 0    3   0  1.4  0.5   3
# 1    2   1  2.1  1.4   1
# 2    1   1  1.7  2.1   0
# 3    0   0  1.6  0.3   0
# 4    2   2  1.0  1.4   0
# 5    2   4  1.1  4.2  -2
# 6    3   2  1.8  1.3   1
# 7    1   0  1.1  2.0   1
# 8    2   2  1.3  1.3   0
# 9    1   2  1.0  1.6  -1
# 10   2   1  2.3  2.1   1
# 11   2   1  0.9  1.6   1
# 12   1   1  1.7  1.0   0
# 13   1   3  1.4  1.1  -2
# 14   2   2  1.5  1.3   0
# 15   1   3  1.0  2.2  -2
# 16   1   1  0.9  1.2   0
# 17   0   0  1.3  1.1   0
# 18   2   2  1.1  1.8   0
# 19   1   1  1.5  0.9   0
# 20   2   0  1.0  0.3   2
# 21   3   1  1.9  1.5   2
# 22   0   1  0.7  0.8  -1
# 23   0   7  0.9  3.3  -7
# 24   3   0  1.4  0.5   3
# 25   4   0  3.9  0.1   4
# 26   2   1  2.4  1.5   1
# 27   2   1  1.5  0.9   1
# 28   2   2  2.0  1.7   0
# 29   0   3  0.9  1.2  -3
# 30   1   2  1.0  0.6  -1
# 31   2   2  3.8  1.5   0
# 32   2   4  1.4  2.1  -2
# 33   3   2  1.4  1.2   1

# %%
sns.scatterplot(data=goals,x="Round", y="xG")
plt.xticks(rotation=90)
plt.show()
